# %% [markdown]
# This Notebook Contains Routines for Loading and Parsing Autofz log files

# %%
# Load required module(s)
import json
import pandas as pd
from io import StringIO
import os
import jinja2

# Create a dataframe for Unique Bugs metric
ub_df = pd.DataFrame([], columns=('benchmark', 'algorithm', 'discrim', 'unique_bugs', 'run_time'))

# Where do we want to start looking for Autofz Logs?
top_dir = "amd64"

# Create a list of files to parse (ref: 
# https://stackoverflow.com/questions/16953842/using-os-walk-to-recursively-traverse-directories-in-python and
# https://stackoverflow.com/questions/1192978/python-get-relative-path-of-all-files-and-subfolders-in-a-directory
#
jsons = []
for root, dirs, files in os.walk(top_dir):
   for file in files:
    if (str(file))[-4:] == "json":
        rel_dir = os.path.relpath(root, '.')
        rel_file = os.path.join(rel_dir, file)
        jsons.append('./'+rel_file)

print(jsons)
# Out:
# ['./amd64/target_infocap/ub0/infotocap_2024-04-22-19-41-39.json', './amd64/target_infocap/bitmap-ub0/infotocap_2024-04-22-19-41-12.json', './amd64/target_infocap/0/infotocap_2024-04-12-07-33-39.json', './amd64/target_infocap/7/infotocap_2024-04-12-07-34-06.json', './amd64/target_infocap/6/infotocap_2024-04-12-07-34-06.json', './amd64/target_infocap/1/infotocap_2024-04-12-07-33-54.json', './amd64/target_infocap/8/infotocap_2024-04-12-07-34-18.json', './amd64/target_infocap/ub-bitmap0/infotocap_2024-04-22-19-41-36.json', './amd64/target_infocap/draw/infotocap_2024-04-12-07-34-18.json', './amd64/target_infocap/draw/infotocap_2024-04-22-19-41-36.json', './amd64/target_infocap/draw/infotocap_2024-04-22-19-41-39.json', './amd64/target_infocap/draw/infotocap_2024-04-12-07-34-06.json', './amd64/target_infocap/draw/infotocap_2024-04-22-19-41-12.json', './amd64/target_infocap/4/infotocap_2024-04-12-07-34-03.json', './amd64/target_infocap/3/infotocap_2024-04-12-07-34-03.json', './amd64/target_infocap/2/infotocap_2024-04-12-07-33-58.json', './amd64/target_infocap/5/infotocap_2024-04-12-07-34-05.json', './amd64/target_mp3gain/output_algo_autofz-ub/9/mp3gain_2024-05-02-00-34-08.json', './amd64/target_mp3gain/output_algo_autofz-ub/7/mp3gain_2024-04-30-00-22-22.json', './amd64/target_mp3gain/output_algo_autofz-ub/6/mp3gain_2024-04-29-00-16-10.json', './amd64/target_mp3gain/output_algo_autofz-ub/8/mp3gain_2024-05-01-00-28-05.json', './amd64/target_mp3gain/output_algo_autofz-ub/4/mp3gain_2024-04-27-00-03-59.json', './amd64/target_mp3gain/output_algo_autofz-ub/3/mp3gain_2024-04-25-23-57-56.json', './amd64/target_mp3gain/output_algo_autofz-ub/5/mp3gain_2024-04-28-00-10-04.json', './amd64/target_mp3gain/7/output_algo_autofz-ub-bitmap/mp3gain_2024-04-25-00-09-57.json', './amd64/target_mp3gain/output_algo_autofz-ub-bitmap/9/mp3gain_2024-05-02-08-17-12.json', './amd64/target_mp3gain/output_algo_autofz-ub-bitmap/7/mp3gain_2024-04-30-08-05-42.json', './amd64/target_mp3gain/output_algo_autofz-ub-bitmap/6/mp3gain_2024-04-29-07-59-34.json', './amd64/target_mp3gain/output_algo_autofz-ub-bitmap/10/mp3gain_2024-05-02-13-34-36.json', './amd64/target_mp3gain/output_algo_autofz-ub-bitmap/8/mp3gain_2024-05-01-08-11-29.json', './amd64/target_mp3gain/output_algo_autofz-ub-bitmap/4/mp3gain_2024-04-27-07-48-07.json', './amd64/target_mp3gain/output_algo_autofz-ub-bitmap/3/mp3gain_2024-04-26-00-46-45.json', './amd64/target_mp3gain/output_algo_autofz-ub-bitmap/5/mp3gain_2024-04-28-07-54-12.json', './amd64/target_mp3gain/6/output_algo_autofz-ub/mp3gain_2024-04-24-23-38-19.json', './amd64/target_mp3gain/1/output_algo_autofz-bitmap/mp3gain_2024-04-23-21-54-54.json', './amd64/target_mp3gain/8/output_algo_autofz-bitmap-ub/mp3gain_2024-04-25-01-51-50.json', './amd64/target_mp3gain/4/output_algo_autofz-bitmap-ub/mp3gain_2024-04-23-22-29-50.json', './amd64/target_mp3gain/3/output_algo_autofz-ub-bitmap/mp3gain_2024-04-23-22-20-53.json', './amd64/target_mp3gain/output_algo_autofz-bitmap-ub/9/mp3gain_2024-05-02-09-14-30.json', './amd64/target_mp3gain/output_algo_autofz-bitmap-ub/7/mp3gain_2024-04-30-09-02-37.json', './amd64/target_mp3gain/output_algo_autofz-bitmap-ub/6/mp3gain_2024-04-29-08-56-05.json', './amd64/target_mp3gain/output_algo_autofz-bitmap-ub/8/mp3gain_2024-05-01-09-08-19.json', './amd64/target_mp3gain/output_algo_autofz-bitmap-ub/4/mp3gain_2024-04-27-08-44-34.json', './amd64/target_mp3gain/output_algo_autofz-bitmap-ub/3/mp3gain_2024-04-26-08-38-29.json', './amd64/target_mp3gain/output_algo_autofz-bitmap-ub/5/mp3gain_2024-04-28-08-50-43.json', './amd64/target_mp3gain/output_algo_autofz-bitmap/9/mp3gain_2024-05-02-00-30-53.json', './amd64/target_mp3gain/output_algo_autofz-bitmap/7/mp3gain_2024-04-30-00-19-41.json', './amd64/target_mp3gain/output_algo_autofz-bitmap/6/mp3gain_2024-04-29-00-13-26.json', './amd64/target_mp3gain/output_algo_autofz-bitmap/8/mp3gain_2024-05-01-00-25-23.json', './amd64/target_mp3gain/output_algo_autofz-bitmap/4/mp3gain_2024-04-27-00-02-12.jso ...

# %%
# Read in Json file(s)

for log in jsons:
    print("Processing: "+log)
    with open(log, "r") as file:
        autofz_log = json.load(file)
    
    benchmark = autofz_log['autofz_args']['target']
    algorithm = autofz_log['algorithm']
    
    if 'discriminator' in autofz_log['autofz_args']:
        discrim = autofz_log['autofz_args']['discriminator']
    else:
        discrim = 'bitmap'
        
    unique_bugs = autofz_log['log'][-1]['global_unique_bugs']['unique_bugs']
    
    try: # We need to test this in case there are incomplete fuzzing logs
        run_time = float(autofz_log['end_time']) - float(autofz_log['start_time'])
        #print("run_time is: ")

        ub_df = pd.concat([ub_df, pd.DataFrame({'benchmark': [benchmark], 
                                                'algorithm': [algorithm], 
                                                'discrim': [discrim], 
                                                'unique_bugs': [unique_bugs], 
                                                'run_time': [run_time]})])
    except:
        pass

ub_df.describe()
# Out:
# Processing: ./amd64/target_infocap/ub0/infotocap_2024-04-22-19-41-39.json
# Processing: ./amd64/target_infocap/bitmap-ub0/infotocap_2024-04-22-19-41-12.json
# Processing: ./amd64/target_infocap/0/infotocap_2024-04-12-07-33-39.json
# Processing: ./amd64/target_infocap/7/infotocap_2024-04-12-07-34-06.json
# Processing: ./amd64/target_infocap/6/infotocap_2024-04-12-07-34-06.json
# Processing: ./amd64/target_infocap/1/infotocap_2024-04-12-07-33-54.json
# Processing: ./amd64/target_infocap/8/infotocap_2024-04-12-07-34-18.json
# Processing: ./amd64/target_infocap/ub-bitmap0/infotocap_2024-04-22-19-41-36.json
# Processing: ./amd64/target_infocap/draw/infotocap_2024-04-12-07-34-18.json
# Processing: ./amd64/target_infocap/draw/infotocap_2024-04-22-19-41-36.json
# /var/folders/wr/zlg2x6lj0klfcp9bjzbm51kh0000gn/T/ipykernel_80521/2217429071.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ub_df = pd.concat([ub_df, pd.DataFrame({'benchmark': [benchmark],
# Processing: ./amd64/target_infocap/draw/infotocap_2024-04-22-19-41-39.json
# Processing: ./amd64/target_infocap/draw/infotocap_2024-04-12-07-34-06.json
# Processing: ./amd64/target_infocap/draw/infotocap_2024-04-22-19-41-12.json
# Processing: ./amd64/target_infocap/4/infotocap_2024-04-12-07-34-03.json
# Processing: ./amd64/target_infocap/3/infotocap_2024-04-12-07-34-03.json
# Processing: ./amd64/target_infocap/2/infotocap_2024-04-12-07-33-58.json
# Processing: ./amd64/target_infocap/5/infotocap_2024-04-12-07-34-05.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub/9/mp3gain_2024-05-02-00-34-08.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub/7/mp3gain_2024-04-30-00-22-22.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub/6/mp3gain_2024-04-29-00-16-10.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub/8/mp3gain_2024-05-01-00-28-05.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub/4/mp3gain_2024-04-27-00-03-59.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub/3/mp3gain_2024-04-25-23-57-56.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub/5/mp3gain_2024-04-28-00-10-04.json
# Processing: ./amd64/target_mp3gain/7/output_algo_autofz-ub-bitmap/mp3gain_2024-04-25-00-09-57.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub-bitmap/9/mp3gain_2024-05-02-08-17-12.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub-bitmap/7/mp3gain_2024-04-30-08-05-42.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub-bitmap/6/mp3gain_2024-04-29-07-59-34.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub-bitmap/10/mp3gain_2024-05-02-13-34-36.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub-bitmap/8/mp3gain_2024-05-01-08-11-29.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub-bitmap/4/mp3gain_2024-04-27-07-48-07.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub-bitmap/3/mp3gain_2024-04-26-00-46-45.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-ub-bitmap/5/mp3gain_2024-04-28-07-54-12.json
# Processing: ./amd64/target_mp3gain/6/output_algo_autofz-ub/mp3gain_2024-04-24-23-38-19.json
# Processing: ./amd64/target_mp3gain/1/output_algo_autofz-bitmap/mp3gain_2024-04-23-21-54-54.json
# Processing: ./amd64/target_mp3gain/8/output_algo_autofz-bitmap-ub/mp3gain_2024-04-25-01-51-50.json
# Processing: ./amd64/target_mp3gain/4/output_algo_autofz-bitmap-ub/mp3gain_2024-04-23-22-29-50.json
# Processing: ./amd64/target_mp3gain/3/output_algo_autofz-ub-bitmap/mp3gain_2024-04-23-22-20-53.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap-ub/9/mp3gain_2024-05-02-09-14-30.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap-ub/7/mp3gain_2024-04-30-09-02-37.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap-ub/6/mp3gain_2024-04-29-08-56-05.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap-ub/8/mp3gain_2024-05-01-09-08-19.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap-ub/4/mp3gain_2024-04-27-08-44-34.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap-ub/3/mp3gain_2024-04-26-08-38-29.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap-ub/5/mp3gain_2024-04-28-08-50-43.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap/9/mp3gain_2024-05-02-00-30-53.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap/7/mp3gain_2024-04-30-00-19-41.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap/6/mp3gain_2024-04-29-00-13-26.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap/8/mp3gain_2024-05-01-00-25-23.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap/4/mp3gain_2024-04-27-00-02-12.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap/3/mp3gain_2024-04-25-23-56-42.json
# Processing: ./amd64/target_mp3gain/output_algo_autofz-bitmap/5/mp3gain_2024-04-28-00-07-40.json
# Processing: ./amd64/target_mp3gain/2/output_algo_autofz-ub/mp3gain_2024-04-23-22-18-08.json
# Processing: ./amd64/target_mp3gain/5/output_algo_autofz-bitmap/mp3gain_2024-04-24-22-21-03.json
# Processing: ./amd64/target_tcpdump/ub1/tcpdump_2024-04-21-18-53-18.json
# Processing: ./amd64/target_tcpdump/ub0/tcpdump_2024-04-21-18-53-18.json
# Processing: ./amd64/target_tcpdump/bitmap-ub0/tcpdump_2024-04-21-18-56-11.json
# Processing: ./amd64/target_tcpdump/bitmap-ub1/tcpdump_2024-04-21-18-56-11.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-06-24.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-06-04.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-05-39.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-06-48.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-05-08.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-05-49.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-05-26.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-06-37.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-06-17.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-06-17 copy.json
# Processing: ./amd64/target_tcpdump/amd64/tcpdump_2024-04-10-19-04-56.json
# Processing: ./amd64/target_tcpdump/ub-bitmap1/tcpdump_2024-04-21-18-54-31.json
# Processing: ./amd64/target_tcpdump/ub-bitmap0/tcpdump_2024-04-21-18-54-31.json
# Processing: ./amd64/target_tcpdump/draw/tcpdump_2024-04-21-18-56-11.json
# Processing: ./amd64/target_tcpdump/draw/tcpdump_2024-04-21-18-54-31.json
# Processing: ./amd64/target_tcpdump/draw/tcpdump_2024-04-10-19-05-08.json
# Processing: ./amd64/target_tcpdump/draw/tcpdump_2024-04-21-18-53-18.json
# Processing: ./amd64/target_tcpdump/draw/tcpdump_2024-04-10-19-05-26.json
# Processing: ./amd64/target_exiv2/7/output_algo_autofz-bitmap-ub/exiv2_2024-04-22-08-18-39.json
# Processing: ./amd64/target_exiv2/6/output_algo_autofz-ub-bitmap/exiv2_2024-04-22-08-17-55.json
# Processing: ./amd64/target_exiv2/1/output_algo_redqueen/exiv2_2024-02-26-07-25-15.json
# Processing: ./amd64/target_exiv2/1/output_algo_afl/exiv2_2024-02-27-14-19-15.json
# Processing: ./amd64/target_exiv2/1/output_algo_lafintel/exiv2_2024-02-27-14-24-07.json
# Processing: ./amd64/target_exiv2/1/output_algo_angora/exiv2_2024-02-27-14-33-46.json
# Processing: ./amd64/target_exiv2/1/output_algo_aflfast/exiv2_2024-02-27-14-18-48.json
# Processing: ./amd64/target_exiv2/1/output_algo_autofz/exiv2_2024-02-26-07-22-05.json
# Processing: ./amd64/target_exiv2/1/output_algo_learnafl/exiv2_2024-02-26-07-24-33.json
# Processing: ./amd64/target_exiv2/1/output_algo_mopt/exiv2_2024-02-26-07-25-58.json
# Processing: ./amd64/target_exiv2/4/output_algo_autofz-bitmap/exiv2_2024-04-22-08-19-07.json
# Processing: ./amd64/target_exiv2/3/output_algo_redqueen/exiv2_2024-03-17-15-49-25.json
# Processing: ./amd64/target_exiv2/3/output_algo_lafintel/exiv2_2024-03-17-15-52-15.json
# Processing: ./amd64/target_exiv2/3/output_algo_radamsa/exiv2_2024-03-17-15-53-34.json
# Processing: ./amd64/target_exiv2/3/output_algo_aflfast/exiv2_2024-03-17-15-51-17.json
# Processing: ./amd64/target_exiv2/3/output_algo_autofz/exiv2_2024-03-17-15-48-05.json
# Processing: ./amd64/target_exiv2/3/output_algo_learnafl/exiv2_2024-03-17-15-48-38.json
# Processing: ./amd64/target_exiv2/3/output_algo_fairfuzz/exiv2_2024-03-17-15-52-55.json
# Processing: ./amd64/target_exiv2/3/output_algo_mopt/exiv2_2024-03-17-15-50-13.json
# Processing: ./amd64/target_exiv2/2/output_algo_autofz/exiv2_2024-02-29-10-37-25.json
# Processing: ./amd64/target_exiv2/5/output_algo_autofz-ub/exiv2_2024-04-22-08-17-29.json
#            run_time
# count     97.000000
# mean   83467.199795
# std    14176.665446
# min      365.196688
# 25%    86716.375062
# 50%    86732.394901
# 75%    86751.646265
# max    86779.601206

# %%
# We only care about runs that took 24 hours to run
ub_df = ub_df.loc[ub_df['run_time'] >= 86400]

# We also only care about cases where discriminator is bitmap (for now).
# Get the average number of unique bugs found

av_ub_series = ub_df.loc[ub_df['discrim'] == 'bitmap'].groupby(['benchmark', 'algorithm'])['unique_bugs'].mean()
count_series = ub_df.loc[ub_df['discrim'] == 'bitmap'].groupby(['benchmark', 'algorithm'])['unique_bugs'].sum()

benchmarks = ub_df['benchmark'].unique()
algorithms = ub_df['algorithm'].unique()

t_df = pd.DataFrame([], columns=(algorithms))

# Reference: https://stackoverflow.com/questions/13842088/set-value-for-particular-cell-in-pandas-dataframe-using-index
for b in benchmarks:
    t_df = pd.concat([t_df, pd.DataFrame({}, index=[b])])
    for a in algorithms:
        try:
            t_df.at[b, a] = av_ub_series[b, a]
        except:
            pass
t_df
# Out:
#               autofz redqueen  afl lafintel angora aflfast learnafl mopt  \
# infotocap   4.090909      NaN  NaN      NaN    NaN     NaN      NaN  NaN
# mp3gain        8.375      NaN  NaN      NaN    NaN     NaN      NaN  NaN
# tcpdump     0.153846      NaN  NaN      NaN    NaN     NaN      NaN  NaN
# exiv2      10.666667     14.0  4.0      3.5   10.0     4.0      4.0  4.5
#
#           radamsa fairfuzz
# infotocap     NaN      NaN
# mp3gain       NaN      NaN
# tcpdump       NaN      NaN
# exiv2         0.0      5.0

# %%
# Return it in LaTex format
print(t_df.to_latex())
# Out:
# \begin{tabular}{lllllllllll}
# \toprule
#  & autofz & redqueen & afl & lafintel & angora & aflfast & learnafl & mopt & radamsa & fairfuzz \\
# \midrule
# infotocap & 4.090909 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN \\
# mp3gain & 8.375000 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN \\
# tcpdump & 0.153846 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN \\
# exiv2 & 10.666667 & 14.000000 & 4.000000 & 3.500000 & 10.000000 & 4.000000 & 4.000000 & 4.500000 & 0.000000 & 5.000000 \\
# \bottomrule
# \end{tabular}

# %%
count_series = ub_df.loc[ub_df['discrim'] == 'bitmap'].groupby(['benchmark', 'algorithm'])['unique_bugs'].sum()

benchmarks = ub_df['benchmark'].unique()
algorithms = ub_df['algorithm'].unique()

t_df = pd.DataFrame([], columns=(algorithms))

# Reference: https://stackoverflow.com/questions/13842088/set-value-for-particular-cell-in-pandas-dataframe-using-index
for b in benchmarks:
    t_df = pd.concat([t_df, pd.DataFrame({}, index=[b])])
    for a in algorithms:
        try:
            t_df.at[b, a] = count_series[b, a]
        except:
            pass
t_df
# Out:
#           autofz redqueen  afl lafintel angora aflfast learnafl mopt radamsa  \
# infotocap     45      NaN  NaN      NaN    NaN     NaN      NaN  NaN     NaN
# mp3gain       67      NaN  NaN      NaN    NaN     NaN      NaN  NaN     NaN
# tcpdump        2      NaN  NaN      NaN    NaN     NaN      NaN  NaN     NaN
# exiv2         32       14    4        7     10       4        8    9       0
#
#           fairfuzz
# infotocap      NaN
# mp3gain        NaN
# tcpdump        NaN
# exiv2            5

# %%
# We only care about runs that took 24 hours to run
ub_df = ub_df.loc[ub_df['run_time'] >= 86400]

#
# Now, let's look at other discriminators
#
# Get the average number of unique bugs found

av_ub_series = ub_df.loc[ub_df['algorithm'] == 'autofz'].groupby(['benchmark', 'discrim'])['unique_bugs'].mean()

benchmarks = ub_df['benchmark'].unique()
discrims = ub_df['discrim'].unique()

t_df = pd.DataFrame([], columns=(discrims))

# Reference: https://stackoverflow.com/questions/13842088/set-value-for-particular-cell-in-pandas-dataframe-using-index
for b in benchmarks:
    t_df = pd.concat([t_df, pd.DataFrame({}, index=[b])])
    for d in discrims:
        try:
            t_df.at[b, d] = av_ub_series[b, d]
        except:
            pass
t_df
# Out:
#              ub bitmap-ub     bitmap ub-bitmap
# infotocap   4.0       4.0   4.090909       5.0
# mp3gain    10.0     9.625      8.375     9.375
# tcpdump     0.0       0.0   0.153846       1.0
# exiv2       7.0      11.0  10.666667      35.0

# %%
# Return it in LaTex format
print(t_df.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
#  & ub & bitmap-ub & bitmap & ub-bitmap \\
# \midrule
# infotocap & 4.000000 & 4.000000 & 4.090909 & 5.000000 \\
# mp3gain & 10.000000 & 9.625000 & 8.375000 & 9.375000 \\
# tcpdump & 0.000000 & 0.000000 & 0.153846 & 1.000000 \\
# exiv2 & 7.000000 & 11.000000 & 10.666667 & 35.000000 \\
# \bottomrule
# \end{tabular}

# %%
count_series = ub_df.loc[ub_df['algorithm'] == 'autofz'].groupby(['benchmark', 'discrim'])['unique_bugs'].sum()

benchmarks = ub_df['benchmark'].unique()
discrims = ub_df['discrim'].unique()

t_df = pd.DataFrame([], columns=(discrims))

# Reference: https://stackoverflow.com/questions/13842088/set-value-for-particular-cell-in-pandas-dataframe-using-index
for b in benchmarks:
    t_df = pd.concat([t_df, pd.DataFrame({}, index=[b])])
    for d in discrims:
        try:
            t_df.at[b, d] = count_series[b, d]
        except:
            pass
t_df
# Out:
#            ub bitmap-ub bitmap ub-bitmap
# infotocap   8         8     45        10
# mp3gain    80        77     67        75
# tcpdump     0         0      2         3
# exiv2       7        11     32        35
